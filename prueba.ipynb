# %%
from chat_bienestar import ChatBienestar

bot = ChatBienestar()
print(bot.procesar_mensaje("hola"))
# Out:
# ¡Hola! 👋 Bienvenido a Yo Soy Bienestar.
#
# Por favor comparte tu número telefónico para verificar que eres cliente Yo Soy Bienestar.

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run app.py

# %%
from chat_bienestar import ChatBienestar

chat = ChatBienestar()

print("=== CHAT Yo Soy Bienestar ===")

while True:
    mensaje_usuario = input("Tú: ")
    respuesta = chat.procesar_mensaje(mensaje_usuario)
    print("Bot:", respuesta)

    if chat.estado == chat.ESTADOS["FINALIZADO"]:
        break
# Out:
# === CHAT Yo Soy Bienestar ===
# Bot: ¡Hola! 👋 Bienvenido a Yo Soy Bienestar.
#
# Por favor comparte tu número telefónico para verificar que eres cliente Yo Soy Bienestar.
# ⏳ Verificando número en la API...
# Bot: ✅ ¡Verificación exitosa!
#
# Hola bienvenido Cliente Yo Soy Bienestar.
#
# 📱 Número: 5519153291
# ⚡ Servicio: MBB
# 🟢 Estado: ACTIVO
#
# ¿Qué operación deseas realizar?
#
# 1️⃣ Reportar problema con recarga
# 2️⃣ Realizar otro tipo de reporte
# 3️⃣ Salir del chat
#
# Por favor selecciona una opción (1, 2 o 3):
# Bot: 📋 Reportar Problema con Recarga
#
# Por favor ingresa el número de referencia de tu recarga:
# ⏳ Verificando recarga en la API...
# Bot: ✅ **Información de Recarga Encontrada**
#
# 📊 **Referencia:** 1010100631767992
# 👤 **Cliente:** Jose Atonio Brito Garcia
# 📱 **Teléfono:** 5579962318
# 💰 **Monto:** $100.0 MXN
# ✅ **Estado:** Completado
# 🔢 **Autorización:** 423179
#
# 📅 **Fechas:**
#    • Creación: 01/09/2025 14:32:46
#    • Operación: 01/09/2025 14:56:38
# ...
